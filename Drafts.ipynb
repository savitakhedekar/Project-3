# %%
import pandas as pd
import requests
import requests
import json
from datetime import datetime

# %%
url_CAN= "https://eodhd.com/api/macro-indicator/CAN?indicator=inflation_consumer_prices_annual&api_token=6683fcf51c7fc6.23396976"
inflation_data_CAN = requests.get(url_CAN).json()
#print(inflation_data_CAN)
list(inflation_data_CAN)
# Out:
# [{'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2023-12-31',
#   'Period': 'Annual',
#   'Value': 0},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2022-12-31',
#   'Period': 'Annual',
#   'Value': 6.8028},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2021-12-31',
#   'Period': 'Annual',
#   'Value': 3.3952},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2020-12-31',
#   'Period': 'Annual',
#   'Value': 0.717},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2019-12-31',
#   'Period': 'Annual',
#   'Value': 1.9493},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2018-12-31',
#   'Period': 'Annual',
#   'Value': 2.2682},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2017-12-31',
#   'Period': 'Annual',
#   'Value': 1.5969},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2016-12-31',
#   'Period': 'Annual',
#   'Value': 1.4288},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2015-12-31',
#   'Period': 'Annual',
#   'Value': 1.1252},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2014-12-31',
#   'Period': 'Annual',
#   'Value': 1.9066},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2013-12-31',
#   'Period': 'Annual',
#   'Value': 0.9383},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2012-12-31',
#   'Period': 'Annual',
#   'Value': 1.5157},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2011-12-31',
#   'Period': 'Annual',
#   'Value': 2.9121},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2010-12-31',
#   'Period': 'Annual',
#   'Value': 1.7769},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2009-12-31',
#   'Period': 'Annual',
#   'Value': 0.2995},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2008-12-31',
#   'Period': 'Annual',
#   'Value': 2.3703},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2007-12-31',
#   'Period': 'Annual',
#   'Value': 2.1384},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2006-12-31',
#   'Period': 'Annual',
#   'Value': 2.002},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2005-12-31',
#   'Period': 'Annual',
#   'Value': 2.2136},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2004-12-31',
#   'Period': 'Annual',
#   'Value': 1.8573},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2003-12-31',
#   'Period': 'Annual',
#   'Value': 2.7586},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2002-12-31',
#   'Period': 'Annual',
#   'Value': 2.2584},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2001-12-31',
#   'Period': 'Annual',
#   'Value': 2.5251},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '2000-12-31',
#   'Period': 'Annual',
#   'Value': 2.7194},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1999-12-31',
#   'Period': 'Annual',
#   'Value': 1.7348},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1998-12-31',
#   'Period': 'Annual',
#   'Value': 0.9959},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1997-12-31',
#   'Period': 'Annual',
#   'Value': 1.6212},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1996-12-31',
#   'Period': 'Annual',
#   'Value': 1.5705},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1995-12-31',
#   'Period': 'Annual',
#   'Value': 2.1488},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1994-12-31',
#   'Period': 'Annual',
#   'Value': 0.1656},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1993-12-31',
#   'Period': 'Annual',
#   'Value': 1.8651},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1992-12-31',
#   'Period': 'Annual',
#   'Value': 1.4901},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1991-12-31',
#   'Period': 'Annual',
#   'Value': 5.6259},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1990-12-31',
#   'Period': 'Annual',
#   'Value': 4.7805},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1989-12-31',
#   'Period': 'Annual',
#   'Value': 4.9836},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1988-12-31',
#   'Period': 'Annual',
#   'Value': 4.0282},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1987-12-31',
#   'Period': 'Annual',
#   'Value': 4.3561},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1986-12-31',
#   'Period': 'Annual',
#   'Value': 4.1948},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1985-12-31',
#   'Period': 'Annual',
#   'Value': 3.962},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1984-12-31',
#   'Period': 'Annual',
#   'Value': 4.3048},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1983-12-31',
#   'Period': 'Annual',
#   'Value': 5.8636},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1982-12-31',
#   'Period': 'Annual',
#   'Value': 10.769},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1981-12-31',
#   'Period': 'Annual',
#   'Value': 12.4716},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1980-12-31',
#   'Period': 'Annual',
#   'Value': 10.1292},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1979-12-31',
#   'Period': 'Annual',
#   'Value': 9.1447},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1978-12-31',
#   'Period': 'Annual',
#   'Value': 8.9737},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1977-12-31',
#   'Period': 'Annual',
#   'Value': 7.9764},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1976-12-31',
#   'Period': 'Annual',
#   'Value': 7.5417},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1975-12-31',
#   'Period': 'Annual',
#   'Value': 10.6722},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1974-12-31',
#   'Period': 'Annual',
#   'Value': 10.9972},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1973-12-31',
#   'Period': 'Annual',
#   'Value': 7.4876},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1972-12-31',
#   'Period': 'Annual',
#   'Value': 4.988},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1971-12-31',
#   'Period': 'Annual',
#   'Value': 2.7049},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1970-12-31',
#   'Period': 'Annual',
#   'Value': 3.346},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1969-12-31',
#   'Period': 'Annual',
#   'Value': 4.5616},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1968-12-31',
#   'Period': 'Annual',
#   'Value': 4.0553},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1967-12-31',
#   'Period': 'Annual',
#   'Value': 3.58},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1966-12-31',
#   'Period': 'Annual',
#   'Value': 3.8157},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1965-12-31',
#   'Period': 'Annual',
#   'Value': 2.3327},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1964-12-31',
#   'Period': 'Annual',
#   'Value': 1.9121},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1963-12-31',
#   'Period': 'Annual',
#   'Value': 1.6282},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1962-12-31',
#   'Period': 'Annual',
#   'Value': 1.0616},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1961-12-31',
#   'Period': 'Annual',
#   'Value': 1.0188},
#  {'CountryCode': 'CAN',
#   'CountryName': 'Canada',
#   'Indicator': 'Inflation, consumer prices (annual %)',
#   'Date': '1960-12-31',
#   'Period': 'Annual',
#   'Value': 1.3587}]

# %%
inflation_data_CAN[1]['CountryName', 'Value']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 inflation_data_CAN[1]['CountryName', 'Value']
#
# KeyError: ('CountryName', 'Value')
